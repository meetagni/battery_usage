# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

import warnings
warnings.filterwarnings('ignore')

# %%
data_1 = pd.read_csv(r"C:\Users\dell\Downloads\4fx8cjprxm-1\40 degC\763_HWFET - Copy.csv")
data_1 = data_1.iloc[1:,:]
data_1
# Out:
#              Time Stamp  Step Status Prog Time Step Time  Cycle  Cycle Level  \
# 1      04-09-2019 16:42  35.0  TABLE   22:27.5   00:01.5    1.0          1.0
# 2      04-09-2019 16:42  35.0  TABLE   22:27.6   00:01.6    1.0          1.0
# 3      04-09-2019 16:42  35.0  TABLE   22:27.7   00:01.7    1.0          1.0
# 4      04-09-2019 16:42  35.0  TABLE   22:27.8   00:01.8    1.0          1.0
# 5      04-09-2019 16:42  35.0  TABLE   22:27.9   00:01.9    1.0          1.0
# ...                 ...   ...    ...       ...       ...    ...          ...
# 99406  04-09-2019 19:28  37.0    PAU   08:07.9   09:59.7    0.0          0.0
# 99407  04-09-2019 19:28  37.0    PAU   08:08.0   09:59.8    0.0          0.0
# 99408  04-09-2019 19:28  37.0    PAU   08:08.1   09:59.9    0.0          0.0
# 99409  04-09-2019 19:28  37.0    PAU   08:08.2   10:00.0    0.0          0.0
# 99410  04-09-2019 19:28  37.0    PAU   08:08.2   10:00.0    0.0          0.0
#
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99410 entries, 1 to 99410
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time Stamp   99410 non-null  object
#  1   Step         99410 non-null  float64
#  2   Status       99410 non-null  object
#  3   Prog Time    99410 non-null  object
#  4   Step Time    99410 non-null  object
#  5   Cycle        99410 non-null  float64
#  6   Cycle Level  99410 non-null  float64
#  7   Procedure    99410 non-null  object
#  8   Voltage      99410 non-null  object
#  9   Current      99410 non-null  object
#  10  Temperature  99410 non-null  object
#  11  Capacity     99410 non-null  object
#  12  WhAccu       99410 non-null  object
#  13  Cnt          99410 non-null  object
# dtypes: float64(3), object(11)
# memory usage: 10.6+ MB

# %%
plt.plot(data_1.Voltage)
plt.plot(data_1.Current)
plt.plot(data_1.Capacity)
plt.plot(data_1.Cnt)
plt.legend(labels=['Voltage','Current','Capacity','Cnt'])
plt.show()

# %%
plt.plot(data_1['Voltage'], data_1['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_1['Prog Time'], data_1['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %% [markdown]
# Data-2

# %%
data_2 = pd.read_csv(r"C:\Users\dell\Downloads\4fx8cjprxm-1\40 degC\765_LA92 - Copy.csv")
data_2 = data_2.iloc[1:,:]
data_2
# Out:
#               Time Stamp Step Status Prog Time Step Time Cycle Cycle Level  \
# 1       04-12-2019 04:45   42  TABLE   02:36.2   00:01.8     1           1
# 2       04-12-2019 04:45   42  TABLE   02:36.3   00:01.9     1           1
# 3       04-12-2019 04:45   42  TABLE   02:36.4   00:02.0     1           1
# 4       04-12-2019 04:45   42  TABLE   02:36.5   00:02.1     1           1
# 5       04-12-2019 04:45   42  TABLE   02:36.6   00:02.2     1           1
# ...                  ...  ...    ...       ...       ...   ...         ...
# 149607  04-12-2019 08:55   44    PAU   12:12.9   09:59.7     0           0
# 149608  04-12-2019 08:55   44    PAU   12:13.0   09:59.8     0           0
# 149609  04-12-2019 08:55   44    PAU   12:13.1   09:59.9     0           0
# 149610  04-12-2019 08:55   44    PAU   12:13.2   10:00.0     0           0
# 149611  04-12-2019 08:55   44    PAU   12:13.2   10:00.0     0           0
#
# ...

# %%
plt.plot(data_2.Voltage)
plt.plot(data_2.Current)
plt.plot(data_2.Capacity)
plt.plot(data_2.Cnt)
plt.legend(labels=['Voltage','Current','Capacity','Cnt'])
plt.show()

# %%
plt.plot(data_2['Prog Time'], data_2['Capacity'])
plt.xlabel('VOLTAGE')
bplt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_2['Voltage'], data_2['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %% [markdown]
# Data-3

# %%
data_3 = pd.read_csv(r"C:\Users\dell\Downloads\4fx8cjprxm-1\40 degC\763_UDDS - Copy.csv")
data_3 = data_3.iloc[1:,:]
data_3
# Out:
#               Time Stamp  Step Status Prog Time Step Time  Cycle  Cycle Level  \
# 1       04-09-2019 06:12  28.0  TABLE   52:10.0   00:01.5    1.0          1.0
# 2       04-09-2019 06:12  28.0  TABLE   52:10.1   00:01.6    1.0          1.0
# 3       04-09-2019 06:12  28.0  TABLE   52:10.2   00:01.7    1.0          1.0
# 4       04-09-2019 06:12  28.0  TABLE   52:10.3   00:01.8    1.0          1.0
# 5       04-09-2019 06:12  28.0  TABLE   52:10.4   00:01.9    1.0          1.0
# ...                  ...   ...    ...       ...       ...    ...          ...
# 295673  04-09-2019 14:25  30.0    PAU   04:59.3   09:59.7    0.0          0.0
# 295674  04-09-2019 14:25  30.0    PAU   04:59.4   09:59.8    0.0          0.0
# 295675  04-09-2019 14:25  30.0    PAU   04:59.5   09:59.9    0.0          0.0
# 295676  04-09-2019 14:25  30.0    PAU   04:59.6   10:00.0    0.0          0.0
# 295677  04-09-2019 14:25  30.0    PAU   04:59.6   10:00.0    0.0          0.0
#
# ...

# %%
plt.plot(data_3.Voltage)
plt.plot(data_3.Current)
plt.plot(data_3.Capacity)
plt.plot(data_3.Cnt)
plt.legend(labels=['Voltage','Current','Capacity','Cnt'])
plt.show()

# %%
plt.plot(data_3['Prog Time'], data_3['Capacity'])
plt.xlabel('Prog TIme')
plt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_3['Voltage'], data_3['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %% [markdown]
# Data-4

# %%
data_4 = pd.read_csv(r"C:\Users\dell\Downloads\4fx8cjprxm-1\40 degC\761_HPPC - Copy.csv")
data_4 = data_4.iloc[1:,:]
data_4
# Out:
#              Time Stamp  Step Status Prog Time Step Time  Cycle  Cycle Level  \
# 1      04-03-2019 17:28   1.0    PAU   57:57.4   00:00.1    1.0          1.0
# 2      04-03-2019 17:28   1.0    PAU   57:57.5   00:00.2    1.0          1.0
# 3      04-03-2019 17:28   1.0    PAU   57:57.6   00:00.3    1.0          1.0
# 4      04-03-2019 17:28   1.0    PAU   57:57.7   00:00.4    1.0          1.0
# 5      04-03-2019 17:28   1.0    PAU   57:57.8   00:00.5    1.0          1.0
# ...                 ...   ...    ...       ...       ...    ...          ...
# 51771  04-05-2019 05:58  15.0    PAU   27:38.6   14:00.0    0.0          0.0
# 51772  04-05-2019 05:58  15.0    PAU   27:44.3   14:05.6    0.0          0.0
# 51773  04-05-2019 05:59  15.0    PAU   28:38.6   15:00.0    0.0          0.0
# 51774  04-05-2019 05:59  15.0    PAU   28:38.6   15:00.0    0.0          0.0
# 51775  04-05-2019 05:59  21.0    PAU   28:39.7   00:01.0    0.0          0.0
#
# ...

# %%
plt.plot(data_4.Voltage)
plt.plot(data_4.Current)
plt.plot(data_4.Capacity)
plt.plot(data_4.Cnt)
plt.legend(labels=['Voltage','Current','Capacity','Cnt'])
plt.show()

# %%
plt.plot(data_4['Prog Time'], data_4['Capacity'])
plt.xlabel('Prog TIme')
plt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_4['Voltage'], data_4['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %% [markdown]
# DATA CONVERSION

# %%
data_1[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']] = data_1[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']].astype('float')
data_2[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']] = data_2[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']].astype('float')
data_3[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']] = data_3[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']].astype('float')
data_4[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']] = data_4[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']].astype('float')

data_1['Step Time'] = pd.to_datetime(data_1['Step Time'], format = "%M:%S.%f")
data_1['Prog Time'] = pd.to_datetime(data_1['Prog Time'], format = "%M:%S.%f")

data_2['Step Time'] = pd.to_datetime(data_2['Step Time'], format = "%M:%S.%f")
data_2['Prog Time'] = pd.to_datetime(data_2['Prog Time'], format = "%M:%S.%f")

data_3['Step Time'] = pd.to_datetime(data_3['Step Time'], format = "%M:%S.%f")
data_3['Prog Time'] = pd.to_datetime(data_3['Prog Time'], format = "%M:%S.%f")

data_4['Step Time'] = pd.to_datetime(data_4['Step Time'], format = "%M:%S.%f")
data_4['Prog Time'] = pd.to_datetime(data_4['Prog Time'], format = "%M:%S.%f")

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99410 entries, 1 to 99410
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time Stamp   99410 non-null  object
#  1   Step         99410 non-null  float64
#  2   Status       99410 non-null  object
#  3   Prog Time    99410 non-null  datetime64[ns]
#  4   Step Time    99410 non-null  datetime64[ns]
#  5   Cycle        99410 non-null  float64
#  6   Cycle Level  99410 non-null  float64
#  7   Procedure    99410 non-null  object
#  8   Voltage      99410 non-null  float64
#  9   Current      99410 non-null  float64
#  10  Temperature  99410 non-null  float64
#  11  Capacity     99410 non-null  float64
#  12  WhAccu       99410 non-null  float64
#  13  Cnt          99410 non-null  float64
# dtypes: datetime64[ns](2), float64(9), object(3)
# memory usage: 10.6+ MB

# %% [markdown]
# EDA

# %%
plt.plot(data_1['Voltage'], data_1['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_1['Prog Time'], data_1['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %%
plt.plot(data_1['Current'], data_1['Capacity'])
plt.xlabel('VOLTAGE')
plt.ylabel('CAPACITY')
plt.show()

# %% [markdown]
# ##COMBINING DATA

# %%
data = pd.concat([data_1,data_2, data_3, data_4], axis=0)
data
# Out:
#              Time Stamp  Step Status               Prog Time  \
# 1      04-09-2019 16:42  35.0  TABLE 1900-01-01 00:22:27.500
# 2      04-09-2019 16:42  35.0  TABLE 1900-01-01 00:22:27.600
# 3      04-09-2019 16:42  35.0  TABLE 1900-01-01 00:22:27.700
# 4      04-09-2019 16:42  35.0  TABLE 1900-01-01 00:22:27.800
# 5      04-09-2019 16:42  35.0  TABLE 1900-01-01 00:22:27.900
# ...                 ...   ...    ...                     ...
# 51771  04-05-2019 05:58  15.0    PAU 1900-01-01 00:27:38.600
# 51772  04-05-2019 05:58  15.0    PAU 1900-01-01 00:27:44.300
# 51773  04-05-2019 05:59  15.0    PAU 1900-01-01 00:28:38.600
# 51774  04-05-2019 05:59  15.0    PAU 1900-01-01 00:28:38.600
# 51775  04-05-2019 05:59  21.0    PAU 1900-01-01 00:28:39.700
#
#                     Step Time  Cycle  Cycle Level          Procedure  Voltage  \
# 1     1900-01-01 00:00:01.500    1.0          1.0    Turnigy_CyclesA  4.19391
# ...

# %%
data = data.iloc[:,1:]
data
# Out:
#        Step Status               Prog Time               Step Time  Cycle  \
# 1      35.0  TABLE 1900-01-01 00:22:27.500 1900-01-01 00:00:01.500    1.0
# 2      35.0  TABLE 1900-01-01 00:22:27.600 1900-01-01 00:00:01.600    1.0
# 3      35.0  TABLE 1900-01-01 00:22:27.700 1900-01-01 00:00:01.700    1.0
# 4      35.0  TABLE 1900-01-01 00:22:27.800 1900-01-01 00:00:01.800    1.0
# 5      35.0  TABLE 1900-01-01 00:22:27.900 1900-01-01 00:00:01.900    1.0
# ...     ...    ...                     ...                     ...    ...
# 51771  15.0    PAU 1900-01-01 00:27:38.600 1900-01-01 00:14:00.000    0.0
# 51772  15.0    PAU 1900-01-01 00:27:44.300 1900-01-01 00:14:05.600    0.0
# 51773  15.0    PAU 1900-01-01 00:28:38.600 1900-01-01 00:15:00.000    0.0
# 51774  15.0    PAU 1900-01-01 00:28:38.600 1900-01-01 00:15:00.000    0.0
# 51775  21.0    PAU 1900-01-01 00:28:39.700 1900-01-01 00:00:01.000    0.0
#
#        Cycle Level          Procedure  Voltage  Current  Temperature  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 596473 entries, 1 to 51775
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Step         596473 non-null  float64
#  1   Status       596473 non-null  object
#  2   Prog Time    596473 non-null  datetime64[ns]
#  3   Step Time    596473 non-null  datetime64[ns]
#  4   Cycle        596473 non-null  float64
#  5   Cycle Level  596473 non-null  float64
#  6   Procedure    596473 non-null  object
#  7   Voltage      596473 non-null  float64
#  8   Current      596473 non-null  float64
#  9   Temperature  596473 non-null  float64
#  10  Capacity     596473 non-null  float64
#  11  WhAccu       596473 non-null  float64
#  12  Cnt          596473 non-null  float64
# dtypes: datetime64[ns](2), float64(9), object(2)
# memory usage: 63.7+ MB

# %%
data[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']] = data[['Step','Cycle', 'Cycle Level', 'Voltage','Current','Temperature','Capacity','WhAccu','Cnt']].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 596473 entries, 1 to 51775
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Step         596473 non-null  float64
#  1   Status       596473 non-null  object
#  2   Prog Time    596473 non-null  datetime64[ns]
#  3   Step Time    596473 non-null  datetime64[ns]
#  4   Cycle        596473 non-null  float64
#  5   Cycle Level  596473 non-null  float64
#  6   Procedure    596473 non-null  object
#  7   Voltage      596473 non-null  float64
#  8   Current      596473 non-null  float64
#  9   Temperature  596473 non-null  float64
#  10  Capacity     596473 non-null  float64
#  11  WhAccu       596473 non-null  float64
#  12  Cnt          596473 non-null  float64
# dtypes: datetime64[ns](2), float64(9), object(2)
# memory usage: 63.7+ MB

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

data['Status'] = encoder.fit_transform(data['Status'])
data['Procedure'] = encoder.fit_transform(data['Procedure'])

data
# Out:
#        Step  Status               Prog Time               Step Time  Cycle  \
# 1      35.0       3 1900-01-01 00:22:27.500 1900-01-01 00:00:01.500    1.0
# 2      35.0       3 1900-01-01 00:22:27.600 1900-01-01 00:00:01.600    1.0
# 3      35.0       3 1900-01-01 00:22:27.700 1900-01-01 00:00:01.700    1.0
# 4      35.0       3 1900-01-01 00:22:27.800 1900-01-01 00:00:01.800    1.0
# 5      35.0       3 1900-01-01 00:22:27.900 1900-01-01 00:00:01.900    1.0
# ...     ...     ...                     ...                     ...    ...
# 51771  15.0       2 1900-01-01 00:27:38.600 1900-01-01 00:14:00.000    0.0
# 51772  15.0       2 1900-01-01 00:27:44.300 1900-01-01 00:14:05.600    0.0
# 51773  15.0       2 1900-01-01 00:28:38.600 1900-01-01 00:15:00.000    0.0
# 51774  15.0       2 1900-01-01 00:28:38.600 1900-01-01 00:15:00.000    0.0
# 51775  21.0       2 1900-01-01 00:28:39.700 1900-01-01 00:00:01.000    0.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 596473 entries, 1 to 51775
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Step         596473 non-null  float64
#  1   Status       596473 non-null  int32
#  2   Prog Time    596473 non-null  datetime64[ns]
#  3   Step Time    596473 non-null  datetime64[ns]
#  4   Cycle        596473 non-null  float64
#  5   Cycle Level  596473 non-null  float64
#  6   Procedure    596473 non-null  int32
#  7   Voltage      596473 non-null  float64
#  8   Current      596473 non-null  float64
#  9   Temperature  596473 non-null  float64
#  10  Capacity     596473 non-null  float64
#  11  WhAccu       596473 non-null  float64
#  12  Cnt          596473 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int32(2)
# memory usage: 59.2 MB

# %%
data = data.drop(['Prog Time','Step Time'], axis=1)
data
# Out:
#        Step  Status  Cycle  Cycle Level  Procedure  Voltage  Current  \
# 1      35.0       3    1.0          1.0          3  4.19391 -0.03320
# 2      35.0       3    1.0          1.0          3  4.19391 -0.07662
# 3      35.0       3    1.0          1.0          3  4.19374 -0.08939
# 4      35.0       3    1.0          1.0          3  4.19374 -0.09195
# 5      35.0       3    1.0          1.0          3  4.19374 -0.09195
# ...     ...     ...    ...          ...        ...      ...      ...
# 51771  15.0       2    0.0          0.0          2  4.19405  0.00000
# 51772  15.0       2    0.0          0.0          2  4.19405  0.00000
# 51773  15.0       2    0.0          0.0          2  4.19405  0.00000
# 51774  15.0       2    0.0          0.0          2  4.19405  0.00000
# 51775  21.0       2    0.0          0.0          4  4.19405  0.00000
#
#        Temperature  Capacity    WhAccu   Cnt
# 1         37.54160   0.00000   0.00000   5.0
# 2         37.54160   0.00000  -0.00001   5.0
# ...

# %%
data.isnull().sum()
# Out:
# Step           0
# Status         0
# Cycle          0
# Cycle Level    0
# Procedure      0
# Voltage        0
# Current        0
# Temperature    0
# Capacity       0
# WhAccu         0
# Cnt            0
# dtype: int64

# %%
plt.plot(data.Voltage)
plt.plot(data.Current)
plt.plot(data.Capacity)
plt.plot(data.Cnt)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.plot(data.Voltage)

# %%
plt.plot(data.Current)

# %%
plt.plot(data.Capacity)

# %%
plt.plot(data.Cnt)

# %%
X = data.drop(['Temperature'], axis=1)
y = data['Temperature']

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y = encoder.fit_transform(y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.30,random_state=41)
print("X_train : ",X_train.shape, "y_train : ",y_train.shape, "X_test : ",X_test.shape, "y_test : ",y_test.shape)
# Out:
# X_train :  (417531, 10) y_train :  (417531,) X_test :  (178942, 10) y_test :  (178942,)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = lr, X = X_train, y = y_train, cv = 2)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy: 47.33 %
# Standard Deviation: 0.06 %

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = rf, X = X_train, y = y_train, cv = 2)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# Accuracy: 95.60 %
# Standard Deviation: 0.03 %

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = log, X = X_train, y = y_train, cv = 2)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
# ...

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = svr, X = X_train, y = y_train, cv = 2)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
